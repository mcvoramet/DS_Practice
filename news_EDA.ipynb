# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
the_standard = pd.read_csv('the_standard_business_20-09-21.csv')

# %%
the_standard
# Out:
#        Unnamed: 0        Date  \
# 0               0  20.09.2021
# 1               1  20.09.2021
# 2               2  20.09.2021
# 3               3  20.09.2021
# 4               4  20.09.2021
# ...           ...         ...
# 11113       11113  13.06.2017
# 11114       11114  12.06.2017
# 11115       11115  09.06.2017
# 11116       11116  08.06.2017
# 11117       11117  08.06.2017
#
#                                                    Topic  \
# 0      กรุงศรีลุยยกระดับบริการธุรกรรมการเงินให้ตอบโจท...
# 1      JP เตรียมเปิดขาย IPO ไม่เกิน 115 ล้านหุ้น เข้า...
# 2      เปิดรับนักท่องเที่ยวในกรุงเทพฯ 15 ต.ค. อาจจะไม...
# 3      หุ้น Evergrande ดิ่งอีก 17% ทำจุดต่ำสุดรอบ 11 ...
# 4      กรุงไทยเปิดชำระเงินข้ามแดน ‘ไทย-สิงคโปร์’ ผ่าน...
# ...                                                  ...
# 11113  บัลลังก์ Uber สะเทือนอีกครั้ง หลังบอร์ดเตรียมพ...
# 11114  Alibaba ตั้งเป้าเป็นมหาอำนาจทางเศรษฐกิจอันดับท...
# 11115  ทำไมเราถึงติดเฟซบุ๊ก? รู้จัก ‘Hook Model’ และเ...
# ...

# %%
the_standard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11118 entries, 0 to 11117
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  11118 non-null  int64
#  1   Date        11118 non-null  object
#  2   Topic       11118 non-null  object
#  3   Content     11118 non-null  object
#  4   Tag         11118 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 434.4+ KB

# %%
matichon = pd.read_csv('matichon_business_21-09-21_30-09-21.csv')

# %%
matichon
# Out:
#        Unnamed: 0                       Date  \
# 0               0  2021-09-21T11:21:51+00:00
# 1               1  2021-09-21T11:09:01+00:00
# 2               2  2021-09-21T10:41:56+00:00
# 3               3  2021-09-21T10:28:03+00:00
# 4               4  2021-09-21T10:21:00+00:00
# ...           ...                        ...
# 48804       49146  2015-12-04T11:07:12+00:00
# 48805       49147  2015-12-02T18:40:12+00:00
# 48806       49148  2015-12-02T18:31:29+00:00
# 48807       49149  2015-12-02T15:32:02+00:00
# 48808       49150  2015-08-26T11:19:03+00:00
#
#                                                    Topic  \
# 0      ‘บิ๊กตู่’ นำถก ครม.เต็มคณะ จับตาพิจารณาขยายเพด...
# 1      ธ.ไทยเครดิต จับมือ กรมพัฒนาชุมชน จัดติวสร้างต้...
# 2               จอดป้ายประชาชื่น : ลงทุนโค้งสุดท้ายปี’64
# 3      ไทยครองอันดับ 9 ดัชนีนวัตกรรมโลก เจ้าของอนุสิท...
# 4                               คอฟฟี่เบรก : สั่งแก้ด่วน
# ...                                                  ...
# ...

# %%
matichon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48809 entries, 0 to 48808
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  48809 non-null  int64
#  1   Date        48809 non-null  object
#  2   Topic       48809 non-null  object
#  3   Content     48448 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.5+ MB
